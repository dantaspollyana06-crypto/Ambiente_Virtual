# %%
from bs4 import BeautifulSoup as bs
import requests
import csv
import numpy as np
import pandas as pd

dados = pd.read_csv("projeto_varejo_omnichannel_base_bruta.csv")
arquivo = open(
    "projeto_varejo_omnichannel_base_tratada.csv",
    "w",
    newline="",
    encoding="utf-8")

dados = dados.drop_duplicates(subset=["id_venda", "data_venda", "id_cliente", "cliente_nome", "email", "cidade", "estado", "regiao", "id_produto", "produto_nome", "categoria", "canal_venda", "vendedor", "quantidade", "preco_unitario", "desconto_percentual", "custo_unitario", "status_pedido", "forma_pagamento", "avaliacao_cliente"], keep="first")
dados.to_csv(arquivo, index=False)
dados = pd.read_csv("projeto_varejo_omnichannel_base_tratada.csv")
# Out:
# 'Construir um pipeline de tratamento de dados capaz de:\n\nimportar e diagnosticar a base;\nidentificar duplicidades;\ntratar valores ausentes;\npadronizar textos e categorias;\ncorrigir tipos de dados;\nvalidar regras de negócio;\nidentificar outliers;\ncriar métricas analíticas;\nproduzir estatísticas descritivas;\nexportar uma base final para o Power BI.'
