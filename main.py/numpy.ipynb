# %%
import numpy 


arro= numpy.array([15,69,62,22,25])
element =arro[2]
print(element)
print(arro[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import numpy
#       2
#       3
#       4 arro= numpy.array([15,69,62,22,25])
#
# File ~\Desktop\Projeto.FordEnter_Polly\AmbienteVirtual\main.py\numpy.py:2
#       1 import numpy as np
# ----> 2 a= np.array(["Polly","Yasmin", "Denyse","Sara","Mariana", "Noemy"])
#       3 print (a.dtype)
#       5 b=np.array([[1,2,3,4],[5,6,7,8]])
#
# AttributeError: partially initialized module 'numpy' has no attribute 'array' (most likely due to a circular import)
